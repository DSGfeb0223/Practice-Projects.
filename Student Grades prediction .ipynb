# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.style as stl
# %matplotlib inline
import os
import random
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('grades.xlsx')
df
# Out:
#                                 student_id  assignment1_grade  \
# 0     B73F2C11-70F0-E37D-8B10-1D20AFED50B1          92.733946
# 1     98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1          86.790821
# 2     D0F62040-CEB0-904C-F563-2F8620916C4E          85.512541
# 3     FFDF2B2C-F514-EF7F-6538-A6A53518E9DC          86.030665
# 4     5ECBEEB6-F1CE-80AE-3164-E45E99473FB4          64.813800
# ...                                    ...                ...
# 2310  DE88902E-C7A7-E37A-CFA7-F2C8F2D219F2          77.684611
# 2311  DE88902E-C7A7-E37A-CFA7-F2C8F2D219F2          75.367870
# 2312  EFDA9F93-D0C3-864F-B0F6-2E9AA3E05E31          73.269463
# 2313  1F51E050-78F7-F270-1B90-ED1BC0376763          87.268366
# 2314  DDE0526B-7DA4-80E8-C2A6-D097F3826029          80.318105
#
#       assignment1_submission  assignment2_grade  assignment2_submission  \
# 0    2015-11-02 06:55:34.282          83.030552 2015-11-09 02:22:58.938
# 1    2015-11-29 14:57:44.429          86.290821 2015-12-06 17:41:18.449
# ...

# %%
df.head()
# Out:
#                              student_id  assignment1_grade  \
# 0  B73F2C11-70F0-E37D-8B10-1D20AFED50B1          92.733946
# 1  98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1          86.790821
# 2  D0F62040-CEB0-904C-F563-2F8620916C4E          85.512541
# 3  FFDF2B2C-F514-EF7F-6538-A6A53518E9DC          86.030665
# 4  5ECBEEB6-F1CE-80AE-3164-E45E99473FB4          64.813800
#
#    assignment1_submission  assignment2_grade  assignment2_submission  \
# 0 2015-11-02 06:55:34.282          83.030552 2015-11-09 02:22:58.938
# 1 2015-11-29 14:57:44.429          86.290821 2015-12-06 17:41:18.449
# 2 2016-01-09 05:36:02.389          85.512541 2016-01-09 06:39:44.416
# 3 2016-04-30 06:50:39.801          68.824532 2016-04-30 17:20:38.727
# 4 2015-12-13 17:06:10.750          51.491040 2015-12-14 12:25:12.056
#
#    assignment3_grade  assignment3_submission  assignment4_grade  \
# 0          67.164441 2015-11-12 08:58:33.998          53.011553
# ...

# %%
df.shape
# Out:
# (2315, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2315 entries, 0 to 2314
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   student_id              2315 non-null   object
#  1   assignment1_grade       2315 non-null   float64
#  2   assignment1_submission  2315 non-null   datetime64[ns]
#  3   assignment2_grade       2315 non-null   float64
#  4   assignment2_submission  2315 non-null   datetime64[ns]
#  5   assignment3_grade       2315 non-null   float64
#  6   assignment3_submission  2315 non-null   datetime64[ns]
#  7   assignment4_grade       2315 non-null   float64
#  8   assignment4_submission  2315 non-null   datetime64[ns]
#  9   assignment5_grade       2315 non-null   float64
#  10  assignment5_submission  2315 non-null   datetime64[ns]
#  11  assignment6_grade       2315 non-null   float64
#  12  assignment6_submission  2315 non-null   datetime64[ns]
# ...

# %%
df.describe()
# Out:
#        assignment1_grade         assignment1_submission  assignment2_grade  \
# count        2315.000000                           2315        2315.000000
# mean           74.535732  2015-12-27 14:09:14.167957760          66.849007
# min            14.423297     2015-09-14 23:46:23.696000          12.980967
# 25%            63.670100  2015-10-17 15:29:42.673000192          56.127794
# 50%            77.208365     2015-12-21 14:34:19.016000          68.142124
# 75%            87.502146  2016-02-08 05:34:07.220499968          78.310880
# max           100.695583     2016-08-07 18:57:16.825000          99.936206
# std            16.353252                            NaN          15.959210
#
#               assignment2_submission  assignment3_grade  \
# count                           2315        2315.000000
# mean   2016-01-02 10:25:39.367379200          60.623197
# min       2015-09-15 00:26:05.259000          12.307682
# 25%    2015-10-22 08:00:00.097999872          49.866390
# ...

# %%
numeric = ['assignment1_grade ','assignment2_grade ','assignment3_grade ','assignment4_grade ','assignment5_grade ','assignment6_grade ']

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df[numeric].corr(), annot=True, annot_kws={"fontsize":10}, fmt=".2f", vmin=-1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 2
#       1 plt.figure(figsize=(10,10))
# ----> 2 sns.heatmap(df[numeric].corr(), annot=True, annot_kws={"fontsize":10}, fmt=".2f", vmin=-1)
#       3 plt.show()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
# ...
